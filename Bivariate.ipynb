# %%
import pandas as pd

# %%
dataset=pd.read_csv("PreprocessedHousing.csv")

# %%
dataset
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %%
dataset.cov()
# Out:
#                                         price          area       bedrooms  \
# price                            3.498544e+12  2.175676e+09  505946.425931
# area                             2.175676e+09  4.709512e+06     243.232140
# bedrooms                         5.059464e+05  2.432321e+02       0.544738
# bathrooms                        4.864093e+05  2.113466e+02       0.138674
# stories                          6.826446e+05  1.581294e+02       0.261589
# parking                          6.194673e+05  6.599897e+02       0.088562
# mainroad_yes                     1.936075e+05  2.185582e+02      -0.003096
# guestroom_yes                    1.829747e+05  1.165634e+02       0.022760
# basement_yes                     1.670850e+05  4.914084e+01       0.034299
# hotwaterheating_yes              3.645362e+04 -4.193993e+00       0.007117
# airconditioning_yes              3.941112e+05  2.245072e+02       0.055140
# ...

# %%
correlation = dataset[["price", "area"]].corr()
print(correlation)
# Out:
#           price      area
# price  1.000000  0.535997
# area   0.535997  1.000000

# %%
dataset.corr()
# Out:
#                                     price      area  bedrooms  bathrooms  \
# price                            1.000000  0.535997  0.366494   0.517545
# area                             0.535997  1.000000  0.151858   0.193820
# bedrooms                         0.366494  0.151858  1.000000   0.373930
# bathrooms                        0.517545  0.193820  0.373930   1.000000
# stories                          0.420712  0.083996  0.408564   0.326165
# parking                          0.384394  0.352980  0.139270   0.177496
# mainroad_yes                     0.296898  0.288874 -0.012033   0.042398
# guestroom_yes                    0.255517  0.140297  0.080549   0.126469
# basement_yes                     0.187057  0.047417  0.097312   0.102106
# hotwaterheating_yes              0.093073 -0.009229  0.046049   0.067159
# airconditioning_yes              0.452954  0.222393  0.160603   0.186915
# prefarea_yes                     0.329777  0.234779  0.079023   0.063472
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset['area'], dataset['price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(x = 'mainroad_yes', y = 'price', data = dataset)
plt.subplot(2,3,2)
sns.boxplot(x = 'guestroom_yes', y = 'price', data = dataset)
plt.subplot(2,3,3)
sns.boxplot(x = 'basement_yes', y = 'price', data = dataset)
plt.subplot(2,3,4)
sns.boxplot(x = 'hotwaterheating_yes', y = 'price', data = dataset)
plt.subplot(2,3,5)
sns.boxplot(x = 'airconditioning_yes', y = 'price', data = dataset)
plt.subplot(2,3,6)
sns.boxplot(x = 'furnishingstatus_unfurnished', y = 'price', data = dataset)
plt.show()

# %%
import seaborn as sns
correlation_matrix = dataset[["price", "area", "bedrooms", "bathrooms"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()

# %%
sns.barplot(x="furnishingstatus_unfurnished", hue="guestroom_yes", data=dataset)
plt.show()
